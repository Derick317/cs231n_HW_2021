# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'Stanford CS231n/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Stanford CS231n/assignment1/cs231n/datasets
# /content/drive/My Drive/Stanford CS231n/assignment1

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.345280
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -2.035148 analytic: -2.035148, relative error: 1.224689e-08
# numerical: -3.139684 analytic: -3.139684, relative error: 1.001466e-08
# numerical: 1.362009 analytic: 1.362009, relative error: 2.526195e-08
# numerical: -2.071397 analytic: -2.071397, relative error: 2.450955e-09
# numerical: -1.190528 analytic: -1.190528, relative error: 3.680950e-08
# numerical: -2.234118 analytic: -2.234118, relative error: 3.408778e-09
# numerical: -0.152139 analytic: -0.152139, relative error: 4.950484e-07
# numerical: -0.890688 analytic: -0.890688, relative error: 1.960185e-08
# numerical: 0.763767 analytic: 0.763768, relative error: 2.118961e-08
# numerical: -0.617466 analytic: -0.617466, relative error: 5.925490e-08
# numerical: -0.522289 analytic: -0.522289, relative error: 1.237802e-07
# numerical: -0.001479 analytic: -0.001479, relative error: 1.112117e-05
# numerical: -0.614675 analytic: -0.614675, relative error: 1.249233e-07
# numerical: -1.032336 analytic: -1.032336, relative error: 1.830946e-08
# numerical: -1.025037 analytic: -1.025037, relative error: 5.241865e-08
# numerical: 1.705937 analytic: 1.705937, relative error: 3.446069e-09
# numerical: 0.724060 analytic: 0.724060, relative error: 3.362787e-08
# numerical: -2.808200 analytic: -2.808200, relative error: 1.298983e-08
# numerical: -1.672962 analytic: -1.672962, relative error: 2.346648e-08
# numerical: -2.168017 analytic: -2.168017, relative error: 1.378152e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.345280e+00 computed in 0.172674s
# vectorized loss: 2.345280e+00 computed in 0.013450s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [3e-8, 1e-7, 3e-7, 1e-6]
regularization_strengths = [3e3, 1e4, 2.5e4, 5e4, 1e5]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
for step in range(40):
  lr = 10 ** random.uniform(-7.5, -5)
  reg = 10 ** random.uniform(2, 5)
  softm = Softmax()
  print("Learning rate: ", lr, ", Reg: ", reg)
  loss_hist = softm.train(X_train, y_train, learning_rate=lr, reg=reg, 
                          batch_size=200, num_iters=1001, verbose=True)
  y_train_pred = softm.predict(X_train)
  train_accuracy = np.mean(y_train == y_train_pred)
  y_val_pred = softm.predict(X_val)
  val_accuracy = np.mean(y_val == y_val_pred)
  print('training accuracy: %f, validation accuracy: %f' % (train_accuracy, val_accuracy))
  if best_val < val_accuracy:
    best_val = val_accuracy
    best_softmax = softm
  hyp = (lr, reg)
  accuracy = (train_accuracy, val_accuracy)
  results.update({hyp: accuracy})
  print("\n")

pass

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Learning rate:  1.4080861410090442e-07 , Reg:  1223.4965831674963
# iteration 0 / 1001: loss 42.942235
# iteration 100 / 1001: loss 38.574814
# iteration 200 / 1001: loss 35.617529
# iteration 300 / 1001: loss 33.366937
# iteration 400 / 1001: loss 31.088181
# iteration 500 / 1001: loss 28.843552
# iteration 600 / 1001: loss 26.989617
# iteration 700 / 1001: loss 25.362126
# iteration 800 / 1001: loss 23.724097
# iteration 900 / 1001: loss 22.203969
# iteration 1000 / 1001: loss 20.728409
# training accuracy: 0.264796, validation accuracy: 0.249000
#
#
# Learning rate:  4.916649230078201e-06 , Reg:  153.95786281162214
# iteration 0 / 1001: loss 10.323117
# iteration 100 / 1001: loss 5.755528
# iteration 200 / 1001: loss 4.511348
# iteration 300 / 1001: loss 3.541843
# iteration 400 / 1001: loss 3.152661
# iteration 500 / 1001: loss 2.919109
# iteration 600 / 1001: loss 2.663696
# iteration 700 / 1001: loss 2.476640
# iteration 800 / 1001: loss 2.359417
# iteration 900 / 1001: loss 2.118365
# iteration 1000 / 1001: loss 2.093574
# training accuracy: 0.371388, validation accuracy: 0.359000
#
#
# Learning rate:  2.0898101459958335e-06 , Reg:  8589.809025383502
# iteration 0 / 1001: loss 269.484731
# iteration 100 / 1001: loss 2.190396
# iteration 200 / 1001: loss 2.067598
# iteration 300 / 1001: loss 2.030233
# iteration 400 / 1001: loss 2.038304
# iteration 500 / 1001: loss 2.019786
# iteration 600 / 1001: loss 2.051294
# iteration 700 / 1001: loss 2.064364
# iteration 800 / 1001: loss 1.952754
# iteration 900 / 1001: loss 2.031905
# iteration 1000 / 1001: loss 1.985732
# training accuracy: 0.330531, validation accuracy: 0.351000
#
#
# Learning rate:  1.3894370893500243e-07 , Reg:  250.7390441451303
# iteration 0 / 1001: loss 13.295708
# iteration 100 / 1001: loss 11.606087
# iteration 200 / 1001: loss 10.328664
# iteration 300 / 1001: loss 10.457433
# iteration 400 / 1001: loss 10.327166
# iteration 500 / 1001: loss 9.622510
# iteration 600 / 1001: loss 9.983457
# iteration 700 / 1001: loss 9.872235
# iteration 800 / 1001: loss 9.319635
# iteration 900 / 1001: loss 9.344439
# iteration 1000 / 1001: loss 9.102567
# training accuracy: 0.254571, validation accuracy: 0.264000
#
#
# Learning rate:  3.999981651042016e-08 , Reg:  324.38530229201314
# iteration 0 / 1001: loss 15.090517
# iteration 100 / 1001: loss 14.195183
# iteration 200 / 1001: loss 14.010843
# iteration 300 / 1001: loss 13.614483
# iteration 400 / 1001: loss 13.407570
# iteration 500 / 1001: loss 12.813684
# iteration 600 / 1001: loss 12.909217
# iteration 700 / 1001: loss 12.875675
# iteration 800 / 1001: loss 12.668574
# iteration 900 / 1001: loss 12.544123
# iteration 1000 / 1001: loss 12.511966
# training accuracy: 0.189020, validation accuracy: 0.187000
#
#
# Learning rate:  7.960609666415219e-08 , Reg:  25486.117144225816
# iteration 0 / 1001: loss 786.498605
# iteration 100 / 1001: loss 348.501326
# iteration 200 / 1001: loss 155.192584
# iteration 300 / 1001: loss 69.892594
# iteration 400 / 1001: loss 32.097719
# iteration 500 / 1001: loss 15.398315
# iteration 600 / 1001: loss 7.952629
# iteration 700 / 1001: loss 4.726128
# iteration 800 / 1001: loss 3.217714
# iteration 900 / 1001: loss 2.643387
# iteration 1000 / 1001: loss 2.312158
# training accuracy: 0.332612, validation accuracy: 0.345000
#
#
# Learning rate:  1.2244145314572435e-07 , Reg:  51162.399343217934
# iteration 0 / 1001: loss 1580.727425
# iteration 100 / 1001: loss 128.375010
# iteration 200 / 1001: loss 12.240043
# iteration 300 / 1001: loss 2.974776
# iteration 400 / 1001: loss 2.201847
# iteration 500 / 1001: loss 2.127709
# iteration 600 / 1001: loss 2.158460
# iteration 700 / 1001: loss 2.127287
# iteration 800 / 1001: loss 2.149125
# iteration 900 / 1001: loss 2.134636
# iteration 1000 / 1001: loss 2.167953
# training accuracy: 0.308571, validation accuracy: 0.322000
#
#
# Learning rate:  5.330790847414358e-06 , Reg:  101.99926440232643
# iteration 0 / 1001: loss 9.506321
# iteration 100 / 1001: loss 4.792137
# iteration 200 / 1001: loss 3.856227
# iteration 300 / 1001: loss 3.386722
# iteration 400 / 1001: loss 3.000286
# iteration 500 / 1001: loss 3.006376
# iteration 600 / 1001: loss 2.488676
# iteration 700 / 1001: loss 2.488895
# iteration 800 / 1001: loss 2.351661
# iteration 900 / 1001: loss 2.301141
# iteration 1000 / 1001: loss 2.239267
# training accuracy: 0.370735, validation accuracy: 0.374000
#
#
# Learning rate:  1.4695394140968107e-06 , Reg:  14428.76836367006
# iteration 0 / 1001: loss 453.843736
# iteration 100 / 1001: loss 2.198056
# iteration 200 / 1001: loss 2.033085
# iteration 300 / 1001: loss 2.055726
# iteration 400 / 1001: loss 1.988163
# iteration 500 / 1001: loss 2.168526
# iteration 600 / 1001: loss 2.017305
# iteration 700 / 1001: loss 2.015020
# iteration 800 / 1001: loss 2.099680
# iteration 900 / 1001: loss 2.063463
# iteration 1000 / 1001: loss 2.079986
# training accuracy: 0.327673, validation accuracy: 0.343000
#
#
# Learning rate:  8.947223698250842e-08 , Reg:  597.9902782724658
# iteration 0 / 1001: loss 24.148359
# iteration 100 / 1001: loss 22.218776
# iteration 200 / 1001: loss 21.071239
# iteration 300 / 1001: loss 20.105301
# iteration 400 / 1001: loss 19.776648
# iteration 500 / 1001: loss 19.121374
# iteration 600 / 1001: loss 18.739776
# iteration 700 / 1001: loss 18.405385
# iteration 800 / 1001: loss 17.983788
# iteration 900 / 1001: loss 17.530060
# iteration 1000 / 1001: loss 17.234824
# training accuracy: 0.230551, validation accuracy: 0.220000
#
#
# Learning rate:  1.2206609331376938e-06 , Reg:  7110.178977574573
# iteration 0 / 1001: loss 222.359031
# iteration 100 / 1001: loss 8.448493
# iteration 200 / 1001: loss 2.089648
# iteration 300 / 1001: loss 1.898765
# iteration 400 / 1001: loss 1.931655
# iteration 500 / 1001: loss 2.050716
# iteration 600 / 1001: loss 1.996789
# iteration 700 / 1001: loss 1.985147
# iteration 800 / 1001: loss 1.933862
# iteration 900 / 1001: loss 2.017237
# iteration 1000 / 1001: loss 1.989381
# training accuracy: 0.359694, validation accuracy: 0.381000
#
#
# Learning rate:  9.443489029487557e-06 , Reg:  15524.62284599157
# iteration 0 / 1001: loss 484.306368
# iteration 100 / 1001: loss 5.811409
# iteration 200 / 1001: loss 4.071367
# iteration 300 / 1001: loss 6.307578
# iteration 400 / 1001: loss 4.414522
# iteration 500 / 1001: loss 5.808643
# iteration 600 / 1001: loss 5.085573
# iteration 700 / 1001: loss 4.574997
# iteration 800 / 1001: loss 6.695336
# iteration 900 / 1001: loss 3.446569
# iteration 1000 / 1001: loss 3.583729
# training accuracy: 0.189204, validation accuracy: 0.186000
#
#
# Learning rate:  5.458031802196754e-08 , Reg:  523.8873557027438
# iteration 0 / 1001: loss 22.761545
# iteration 100 / 1001: loss 21.096686
# iteration 200 / 1001: loss 20.084283
# iteration 300 / 1001: loss 19.657719
# iteration 400 / 1001: loss 19.192115
# iteration 500 / 1001: loss 19.057076
# iteration 600 / 1001: loss 18.849361
# iteration 700 / 1001: loss 18.437440
# iteration 800 / 1001: loss 18.453484
# iteration 900 / 1001: loss 17.637930
# iteration 1000 / 1001: loss 17.521735
# training accuracy: 0.203306, validation accuracy: 0.207000
#
#
# Learning rate:  1.848791537255342e-07 , Reg:  42402.81698725853
# iteration 0 / 1001: loss 1310.497162
# iteration 100 / 1001: loss 57.185226
# iteration 200 / 1001: loss 4.428421
# iteration 300 / 1001: loss 2.242275
# iteration 400 / 1001: loss 2.078825
# iteration 500 / 1001: loss 2.118127
# iteration 600 / 1001: loss 2.160991
# iteration 700 / 1001: loss 2.119085
# iteration 800 / 1001: loss 2.132246
# iteration 900 / 1001: loss 2.133986
# iteration 1000 / 1001: loss 2.122526
# training accuracy: 0.314633, validation accuracy: 0.336000
#
#
# Learning rate:  2.3169721174242082e-07 , Reg:  12077.582391066326
# iteration 0 / 1001: loss 373.658280
# iteration 100 / 1001: loss 121.881966
# iteration 200 / 1001: loss 40.762228
# iteration 300 / 1001: loss 14.522918
# iteration 400 / 1001: loss 6.123083
# iteration 500 / 1001: loss 3.330041
# iteration 600 / 1001: loss 2.432126
# iteration 700 / 1001: loss 2.176501
# iteration 800 / 1001: loss 2.030525
# iteration 900 / 1001: loss 2.044887
# iteration 1000 / 1001: loss 2.016835
# training accuracy: 0.352061, validation accuracy: 0.365000
#
#
# Learning rate:  9.53496654207471e-07 , Reg:  16018.1138715476
# iteration 0 / 1001: loss 497.537728
# iteration 100 / 1001: loss 3.013560
# iteration 200 / 1001: loss 2.123919
# iteration 300 / 1001: loss 2.011933
# iteration 400 / 1001: loss 2.004066
# iteration 500 / 1001: loss 1.987001
# iteration 600 / 1001: loss 2.060735
# iteration 700 / 1001: loss 2.067033
# iteration 800 / 1001: loss 2.023398
# iteration 900 / 1001: loss 2.033960
# iteration 1000 / 1001: loss 2.107891
# training accuracy: 0.330510, validation accuracy: 0.345000
#
#
# Learning rate:  3.756574222578333e-08 , Reg:  5746.782621551269
# iteration 0 / 1001: loss 181.145888
# iteration 100 / 1001: loss 165.780462
# iteration 200 / 1001: loss 152.028830
# iteration 300 / 1001: loss 139.218900
# iteration 400 / 1001: loss 127.802363
# iteration 500 / 1001: loss 117.377039
# iteration 600 / 1001: loss 107.403147
# iteration 700 / 1001: loss 98.477972
# iteration 800 / 1001: loss 90.514538
# iteration 900 / 1001: loss 82.905825
# iteration 1000 / 1001: loss 76.168971
# training accuracy: 0.205143, validation accuracy: 0.198000
#
#
# Learning rate:  2.4671847885234703e-07 , Reg:  55872.93592394468
# iteration 0 / 1001: loss 1714.603051
# iteration 100 / 1001: loss 8.522135
# iteration 200 / 1001: loss 2.210918
# iteration 300 / 1001: loss 2.162587
# iteration 400 / 1001: loss 2.143048
# iteration 500 / 1001: loss 2.134527
# iteration 600 / 1001: loss 2.144952
# iteration 700 / 1001: loss 2.170918
# iteration 800 / 1001: loss 2.130954
# iteration 900 / 1001: loss 2.099704
# iteration 1000 / 1001: loss 2.157286
# training accuracy: 0.306980, validation accuracy: 0.317000
#
#
# Learning rate:  2.34842229304612e-06 , Reg:  27633.73093251432
# iteration 0 / 1001: loss 856.006300
# iteration 100 / 1001: loss 2.138179
# iteration 200 / 1001: loss 2.083143
# iteration 300 / 1001: loss 2.195035
# iteration 400 / 1001: loss 2.127809
# iteration 500 / 1001: loss 2.119407
# iteration 600 / 1001: loss 2.109884
# iteration 700 / 1001: loss 2.148136
# iteration 800 / 1001: loss 2.128656
# iteration 900 / 1001: loss 2.151519
# iteration 1000 / 1001: loss 2.107633
# training accuracy: 0.299061, validation accuracy: 0.296000
#
#
# Learning rate:  8.415893204088413e-07 , Reg:  22855.47679721949
# iteration 0 / 1001: loss 698.483356
# iteration 100 / 1001: loss 2.327929
# iteration 200 / 1001: loss 2.092814
# iteration 300 / 1001: loss 2.021769
# iteration 400 / 1001: loss 2.031841
# iteration 500 / 1001: loss 2.119927
# iteration 600 / 1001: loss 2.071630
# iteration 700 / 1001: loss 2.069122
# iteration 800 / 1001: loss 2.059155
# iteration 900 / 1001: loss 2.050007
# iteration 1000 / 1001: loss 2.076657
# training accuracy: 0.325735, validation accuracy: 0.337000
#
#
# Learning rate:  1.2591296727133426e-06 , Reg:  3188.1170914663767
# iteration 0 / 1001: loss 103.128214
# iteration 100 / 1001: loss 20.976895
# iteration 200 / 1001: loss 5.793201
# iteration 300 / 1001: loss 2.637562
# iteration 400 / 1001: loss 1.990226
# iteration 500 / 1001: loss 1.896002
# iteration 600 / 1001: loss 2.078935
# iteration 700 / 1001: loss 1.917965
# iteration 800 / 1001: loss 1.871790
# iteration 900 / 1001: loss 1.930475
# iteration 1000 / 1001: loss 1.939640
# training accuracy: 0.372102, validation accuracy: 0.387000
#
#
# Learning rate:  5.67661471480902e-07 , Reg:  4580.878529774713
# iteration 0 / 1001: loss 145.465064
# iteration 100 / 1001: loss 51.423871
# iteration 200 / 1001: loss 19.011567
# iteration 300 / 1001: loss 7.945989
# iteration 400 / 1001: loss 4.046153
# iteration 500 / 1001: loss 2.699307
# iteration 600 / 1001: loss 2.168513
# iteration 700 / 1001: loss 1.974305
# iteration 800 / 1001: loss 1.948817
# iteration 900 / 1001: loss 1.845347
# iteration 1000 / 1001: loss 1.958436
# training accuracy: 0.376041, validation accuracy: 0.376000
#
#
# Learning rate:  7.768130512800017e-06 , Reg:  3547.9003031497436
# iteration 0 / 1001: loss 113.938037
# iteration 100 / 1001: loss 2.974341
# iteration 200 / 1001: loss 3.177103
# iteration 300 / 1001: loss 3.308324
# iteration 400 / 1001: loss 3.088660
# iteration 500 / 1001: loss 3.022978
# iteration 600 / 1001: loss 3.812125
# iteration 700 / 1001: loss 3.032880
# iteration 800 / 1001: loss 2.575530
# iteration 900 / 1001: loss 2.751840
# iteration 1000 / 1001: loss 2.680274
# training accuracy: 0.304163, validation accuracy: 0.317000
#
#
# Learning rate:  8.915433474722273e-06 , Reg:  19150.397140511574
# iteration 0 / 1001: loss 597.742646
# iteration 100 / 1001: loss 7.102854
# iteration 200 / 1001: loss 5.907717
# iteration 300 / 1001: loss 5.722586
# iteration 400 / 1001: loss 5.718902
# iteration 500 / 1001: loss 3.876162
# iteration 600 / 1001: loss 4.514171
# iteration 700 / 1001: loss 4.842255
# iteration 800 / 1001: loss 5.463109
# iteration 900 / 1001: loss 7.089796
# iteration 1000 / 1001: loss 5.104732
# training accuracy: 0.122571, validation accuracy: 0.102000
#
#
# Learning rate:  2.6131604730828846e-06 , Reg:  2778.2230845801805
# iteration 0 / 1001: loss 90.624916
# iteration 100 / 1001: loss 6.392277
# iteration 200 / 1001: loss 2.263483
# iteration 300 / 1001: loss 1.976965
# iteration 400 / 1001: loss 1.892891
# iteration 500 / 1001: loss 1.940258
# iteration 600 / 1001: loss 1.927420
# iteration 700 / 1001: loss 1.931459
# iteration 800 / 1001: loss 1.921961
# iteration 900 / 1001: loss 1.963046
# iteration 1000 / 1001: loss 1.853433
# training accuracy: 0.364633, validation accuracy: 0.369000
#
#
# Learning rate:  1.7299920220694962e-07 , Reg:  70954.67398510604
# iteration 0 / 1001: loss 2180.575151
# iteration 100 / 1001: loss 17.179398
# iteration 200 / 1001: loss 2.264932
# iteration 300 / 1001: loss 2.163634
# iteration 400 / 1001: loss 2.194783
# iteration 500 / 1001: loss 2.148031
# iteration 600 / 1001: loss 2.172376
# iteration 700 / 1001: loss 2.193143
# iteration 800 / 1001: loss 2.182251
# iteration 900 / 1001: loss 2.172877
# iteration 1000 / 1001: loss 2.202539
# training accuracy: 0.307796, validation accuracy: 0.318000
#
#
# Learning rate:  5.379680344137593e-08 , Reg:  90668.01884635638
# iteration 0 / 1001: loss 2804.634572
# iteration 100 / 1001: loss 395.937937
# iteration 200 / 1001: loss 57.511999
# iteration 300 / 1001: loss 9.944014
# iteration 400 / 1001: loss 3.288030
# iteration 500 / 1001: loss 2.354112
# iteration 600 / 1001: loss 2.210767
# iteration 700 / 1001: loss 2.180494
# iteration 800 / 1001: loss 2.185554
# iteration 900 / 1001: loss 2.172200
# iteration 1000 / 1001: loss 2.213945
# training accuracy: 0.285469, validation accuracy: 0.297000
#
#
# Learning rate:  5.430410437182086e-07 , Reg:  14577.356150541493
# iteration 0 / 1001: loss 446.101875
# iteration 100 / 1001: loss 20.025815
# iteration 200 / 1001: loss 2.741026
# iteration 300 / 1001: loss 1.990627
# iteration 400 / 1001: loss 2.078756
# iteration 500 / 1001: loss 2.024974
# iteration 600 / 1001: loss 2.006015
# iteration 700 / 1001: loss 2.037216
# iteration 800 / 1001: loss 2.122628
# iteration 900 / 1001: loss 2.015239
# iteration 1000 / 1001: loss 1.973015
# training accuracy: 0.347020, validation accuracy: 0.366000
#
#
# Learning rate:  3.668174002183762e-08 , Reg:  5181.578408258877
# iteration 0 / 1001: loss 166.318426
# iteration 100 / 1001: loss 153.415567
# iteration 200 / 1001: loss 142.145356
# iteration 300 / 1001: loss 131.593091
# iteration 400 / 1001: loss 121.671797
# iteration 500 / 1001: loss 112.894479
# iteration 600 / 1001: loss 104.506869
# iteration 700 / 1001: loss 97.406794
# iteration 800 / 1001: loss 89.904203
# iteration 900 / 1001: loss 83.305415
# iteration 1000 / 1001: loss 77.304020
# training accuracy: 0.197776, validation accuracy: 0.208000
#
#
# Learning rate:  1.8868612337803946e-07 , Reg:  17683.152268119313
# iteration 0 / 1001: loss 556.147018
# iteration 100 / 1001: loss 146.133478
# iteration 200 / 1001: loss 39.672329
# iteration 300 / 1001: loss 11.856235
# iteration 400 / 1001: loss 4.594200
# iteration 500 / 1001: loss 2.734491
# iteration 600 / 1001: loss 2.225883
# iteration 700 / 1001: loss 2.066349
# iteration 800 / 1001: loss 2.033956
# iteration 900 / 1001: loss 2.086991
# iteration 1000 / 1001: loss 2.085692
# training accuracy: 0.334837, validation accuracy: 0.353000
#
#
# Learning rate:  1.1214553349578177e-07 , Reg:  1211.0805121578385
# iteration 0 / 1001: loss 42.712235
# iteration 100 / 1001: loss 38.698051
# iteration 200 / 1001: loss 36.160343
# iteration 300 / 1001: loss 34.258280
# iteration 400 / 1001: loss 32.545197
# iteration 500 / 1001: loss 30.662006
# iteration 600 / 1001: loss 29.090682
# iteration 700 / 1001: loss 27.574007
# iteration 800 / 1001: loss 26.002097
# iteration 900 / 1001: loss 24.987029
# iteration 1000 / 1001: loss 23.521769
# training accuracy: 0.255061, validation accuracy: 0.253000
#
#
# Learning rate:  3.813534799424074e-08 , Reg:  250.53822055638045
# iteration 0 / 1001: loss 12.761188
# iteration 100 / 1001: loss 12.139152
# iteration 200 / 1001: loss 11.851216
# iteration 300 / 1001: loss 11.395173
# iteration 400 / 1001: loss 11.228845
# iteration 500 / 1001: loss 11.108124
# iteration 600 / 1001: loss 11.017112
# iteration 700 / 1001: loss 11.036942
# iteration 800 / 1001: loss 10.677325
# iteration 900 / 1001: loss 10.445019
# iteration 1000 / 1001: loss 10.557351
# training accuracy: 0.191939, validation accuracy: 0.215000
#
#
# Learning rate:  5.914356340979693e-07 , Reg:  25082.142450612824
# iteration 0 / 1001: loss 775.993600
# iteration 100 / 1001: loss 3.928626
# iteration 200 / 1001: loss 2.078271
# iteration 300 / 1001: loss 2.040958
# iteration 400 / 1001: loss 2.105513
# iteration 500 / 1001: loss 2.119204
# iteration 600 / 1001: loss 2.102321
# iteration 700 / 1001: loss 2.048608
# iteration 800 / 1001: loss 2.064746
# iteration 900 / 1001: loss 2.085408
# iteration 1000 / 1001: loss 2.134116
# training accuracy: 0.313429, validation accuracy: 0.318000
#
#
# Learning rate:  6.947720480520289e-07 , Reg:  20003.13316309675
# iteration 0 / 1001: loss 621.204376
# iteration 100 / 1001: loss 4.236611
# iteration 200 / 1001: loss 2.113581
# iteration 300 / 1001: loss 2.066526
# iteration 400 / 1001: loss 2.020635
# iteration 500 / 1001: loss 2.028492
# iteration 600 / 1001: loss 2.065625
# iteration 700 / 1001: loss 2.094594
# iteration 800 / 1001: loss 2.130374
# iteration 900 / 1001: loss 2.026661
# iteration 1000 / 1001: loss 2.065183
# training accuracy: 0.330714, validation accuracy: 0.339000
#
#
# Learning rate:  1.7498083490644557e-06 , Reg:  126.46744458032566
# iteration 0 / 1001: loss 10.059207
# iteration 100 / 1001: loss 5.870736
# iteration 200 / 1001: loss 5.383058
# iteration 300 / 1001: loss 4.898763
# iteration 400 / 1001: loss 4.609264
# iteration 500 / 1001: loss 4.376169
# iteration 600 / 1001: loss 4.145008
# iteration 700 / 1001: loss 3.764938
# iteration 800 / 1001: loss 3.478372
# iteration 900 / 1001: loss 3.489151
# iteration 1000 / 1001: loss 3.352166
# training accuracy: 0.376184, validation accuracy: 0.383000
#
#
# Learning rate:  8.356201590064302e-06 , Reg:  828.183420320383
# iteration 0 / 1001: loss 31.276785
# iteration 100 / 1001: loss 4.011462
# iteration 200 / 1001: loss 3.490607
# iteration 300 / 1001: loss 2.713883
# iteration 400 / 1001: loss 2.135183
# iteration 500 / 1001: loss 3.308916
# iteration 600 / 1001: loss 2.380103
# iteration 700 / 1001: loss 2.549318
# iteration 800 / 1001: loss 3.234945
# iteration 900 / 1001: loss 3.347308
# iteration 1000 / 1001: loss 2.379245
# training accuracy: 0.298755, validation accuracy: 0.331000
#
#
# Learning rate:  5.552069875213923e-07 , Reg:  74369.89959070449
# iteration 0 / 1001: loss 2302.107133
# iteration 100 / 1001: loss 2.168392
# iteration 200 / 1001: loss 2.161165
# iteration 300 / 1001: loss 2.183503
# iteration 400 / 1001: loss 2.203791
# iteration 500 / 1001: loss 2.163912
# iteration 600 / 1001: loss 2.165414
# iteration 700 / 1001: loss 2.175767
# iteration 800 / 1001: loss 2.183727
# iteration 900 / 1001: loss 2.158597
# iteration 1000 / 1001: loss 2.200476
# training accuracy: 0.302653, validation accuracy: 0.302000
#
#
# Learning rate:  5.820858897755775e-07 , Reg:  196.88663513157516
# iteration 0 / 1001: loss 12.226060
# iteration 100 / 1001: loss 8.821850
# iteration 200 / 1001: loss 8.329730
# iteration 300 / 1001: loss 7.637479
# iteration 400 / 1001: loss 7.193789
# iteration 500 / 1001: loss 6.780024
# iteration 600 / 1001: loss 6.795634
# iteration 700 / 1001: loss 6.521161
# iteration 800 / 1001: loss 6.303612
# iteration 900 / 1001: loss 5.778739
# iteration 1000 / 1001: loss 5.742844
# training accuracy: 0.318551, validation accuracy: 0.324000
#
#
# Learning rate:  1.5175488403966078e-07 , Reg:  4980.4165672679255
# iteration 0 / 1001: loss 156.678411
# iteration 100 / 1001: loss 114.825345
# iteration 200 / 1001: loss 84.864792
# iteration 300 / 1001: loss 62.953072
# iteration 400 / 1001: loss 46.929927
# iteration 500 / 1001: loss 35.006295
# iteration 600 / 1001: loss 26.433703
# iteration 700 / 1001: loss 20.054636
# iteration 800 / 1001: loss 15.172931
# iteration 900 / 1001: loss 11.641729
# iteration 1000 / 1001: loss 9.248020
# training accuracy: 0.335694, validation accuracy: 0.325000
#
#
# Learning rate:  6.126433393319765e-07 , Reg:  1050.400220576455
# iteration 0 / 1001: loss 38.160305
# iteration 100 / 1001: loss 27.568307
# iteration 200 / 1001: loss 21.336355
# iteration 300 / 1001: loss 16.657919
# iteration 400 / 1001: loss 13.204802
# iteration 500 / 1001: loss 10.560647
# iteration 600 / 1001: loss 8.659889
# iteration 700 / 1001: loss 7.044708
# iteration 800 / 1001: loss 5.790736
# iteration 900 / 1001: loss 4.827920
# iteration 1000 / 1001: loss 4.168144
# training accuracy: 0.376327, validation accuracy: 0.374000
#
#
# lr 3.668174e-08 reg 5.181578e+03 train accuracy: 0.197776 val accuracy: 0.208000
# lr 3.756574e-08 reg 5.746783e+03 train accuracy: 0.205143 val accuracy: 0.198000
# lr 3.813535e-08 reg 2.505382e+02 train accuracy: 0.191939 val accuracy: 0.215000
# lr 3.999982e-08 reg 3.243853e+02 train accuracy: 0.189020 val accuracy: 0.187000
# lr 5.379680e-08 reg 9.066802e+04 train accuracy: 0.285469 val accuracy: 0.297000
# lr 5.458032e-08 reg 5.238874e+02 train accuracy: 0.203306 val accuracy: 0.207000
# lr 7.960610e-08 reg 2.548612e+04 train accuracy: 0.332612 val accuracy: 0.345000
# lr 8.947224e-08 reg 5.979903e+02 train accuracy: 0.230551 val accuracy: 0.220000
# lr 1.121455e-07 reg 1.211081e+03 train accuracy: 0.255061 val accuracy: 0.253000
# lr 1.224415e-07 reg 5.116240e+04 train accuracy: 0.308571 val accuracy: 0.322000
# lr 1.389437e-07 reg 2.507390e+02 train accuracy: 0.254571 val accuracy: 0.264000
# lr 1.408086e-07 reg 1.223497e+03 train accuracy: 0.264796 val accuracy: 0.249000
# lr 1.517549e-07 reg 4.980417e+03 train accuracy: 0.335694 val accuracy: 0.325000
# lr 1.729992e-07 reg 7.095467e+04 train accuracy: 0.307796 val accuracy: 0.318000
# lr 1.848792e-07 reg 4.240282e+04 train accuracy: 0.314633 val accuracy: 0.336000
# lr 1.886861e-07 reg 1.768315e+04 train accuracy: 0.334837 val accuracy: 0.353000
# lr 2.316972e-07 reg 1.207758e+04 train accuracy: 0.352061 val accuracy: 0.365000
# lr 2.467185e-07 reg 5.587294e+04 train accuracy: 0.306980 val accuracy: 0.317000
# lr 5.430410e-07 reg 1.457736e+04 train accuracy: 0.347020 val accuracy: 0.366000
# lr 5.552070e-07 reg 7.436990e+04 train accuracy: 0.302653 val accuracy: 0.302000
# lr 5.676615e-07 reg 4.580879e+03 train accuracy: 0.376041 val accuracy: 0.376000
# lr 5.820859e-07 reg 1.968866e+02 train accuracy: 0.318551 val accuracy: 0.324000
# lr 5.914356e-07 reg 2.508214e+04 train accuracy: 0.313429 val accuracy: 0.318000
# lr 6.126433e-07 reg 1.050400e+03 train accuracy: 0.376327 val accuracy: 0.374000
# lr 6.947720e-07 reg 2.000313e+04 train accuracy: 0.330714 val accuracy: 0.339000
# lr 8.415893e-07 reg 2.285548e+04 train accuracy: 0.325735 val accuracy: 0.337000
# lr 9.534967e-07 reg 1.601811e+04 train accuracy: 0.330510 val accuracy: 0.345000
# lr 1.220661e-06 reg 7.110179e+03 train accuracy: 0.359694 val accuracy: 0.381000
# lr 1.259130e-06 reg 3.188117e+03 train accuracy: 0.372102 val accuracy: 0.387000
# lr 1.469539e-06 reg 1.442877e+04 train accuracy: 0.327673 val accuracy: 0.343000
# lr 1.749808e-06 reg 1.264674e+02 train accuracy: 0.376184 val accuracy: 0.383000
# lr 2.089810e-06 reg 8.589809e+03 train accuracy: 0.330531 val accuracy: 0.351000
# lr 2.348422e-06 reg 2.763373e+04 train accuracy: 0.299061 val accuracy: 0.296000
# lr 2.613160e-06 reg 2.778223e+03 train accuracy: 0.364633 val accuracy: 0.369000
# lr 4.916649e-06 reg 1.539579e+02 train accuracy: 0.371388 val accuracy: 0.359000
# lr 5.330791e-06 reg 1.019993e+02 train accuracy: 0.370735 val accuracy: 0.374000
# lr 7.768131e-06 reg 3.547900e+03 train accuracy: 0.304163 val accuracy: 0.317000
# lr 8.356202e-06 reg 8.281834e+02 train accuracy: 0.298755 val accuracy: 0.331000
# lr 8.915433e-06 reg 1.915040e+04 train accuracy: 0.122571 val accuracy: 0.102000
# lr 9.443489e-06 reg 1.552462e+04 train accuracy: 0.189204 val accuracy: 0.186000
# best validation accuracy achieved during cross-validation: 0.387000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.375000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$ *True.*
#
#
# $\color{blue}{\textit Your Explanation:}$ *Because the loss function of a single point of the softmax is always larger than zero, but for SVM, the loss function for one single point can *

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
